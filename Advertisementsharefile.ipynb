# %%
import numpy as np   # Numerical Python
import pandas as pd  # Data Manipulation tool
import seaborn as sns # Data Visulization
import matplotlib.pyplot as plt  # Data Visulization
from pandas_profiling import ProfileReport # Data Reporting

# %%
Data = pd.read_csv("https://raw.githubusercontent.com/reddyprasade/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/Advertising.csv")

# %%
Data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
Data.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
Data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
Data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
Data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
sns.pairplot(Data)

# %%
sns.heatmap(np.corrcoef(Data))

# %%
ProfileReport(Data)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='variables', max=4.0, style=ProgressStyle(description_widt…
# HBox(children=(FloatProgress(value=0.0, description='correlations', max=6.0, style=ProgressStyle(description_w…
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\numba\core\typeconv\typeconv.py in <module>
#       3     # Numba, if it fails to import, provide some feedback
# ----> 4     from numba.core.typeconv import _typeconv
#       5 except ImportError as e:
#
# ImportError: DLL load failed: The specified module could not be found.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-e3167fde86f8> in <module>
# ----> 1 ProfileReport(Data)
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\pandas_profiling\__init__.py in __init__(self, df, minimal, config_file, **kwargs)
#      61
#      62         # Get dataset statistics
# ---> 63         description_set = describe_df(df)
#      64
#      65         # Build report structure
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\pandas_profiling\model\describe.py in describe(df)
#     620
#     621     # Get correlations
# --> 622     correlations = calculate_correlations(df, variables)
#     623
#     624     # Scatter matrix
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\pandas_profiling\model\correlations.py in calculate_correlations(df, variables)
#     183                         warn_correlation(correlation_name, e)
#     184                 elif correlation_name in ["phi_k"]:
# --> 185                     import phik
#     186
#     187                     with warnings.catch_warnings():
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\phik\__init__.py in <module>
#       3
#       4 # pandas dataframe decorators
# ----> 5 from phik import decorators
#       6
#       7 # array functions
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\phik\decorators\__init__.py in <module>
#       2
#       3 # import pandas DataFrame decorators
# ----> 4 from phik.decorators import pandas
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\phik\decorators\pandas.py in <module>
#      28
#      29 # add significance matrix function for variable dependencies
# ---> 30 from phik.significance import significance_matrix
#      31 DataFrame.significance_matrix = significance_matrix
#      32
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\phik\significance.py in <module>
#      29 from .statistics import get_chi2_using_dependent_frequency_estimates
#      30 from .statistics import estimate_ndof, theoretical_ndof
# ---> 31 from .simulation import sim_chi2_distribution
#      32 from .data_quality import dq_check_nunique_values, dq_check_hist2d
#      33
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\phik\simulation.py in <module>
#      17 import numpy as np
#      18 import pandas as pd
# ---> 19 from numba import jit
#      20 from joblib import Parallel, delayed
#      21
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\numba\__init__.py in <module>
#      18
#      19 # Re-export typeof
# ---> 20 from numba.misc.special import (
#      21     typeof, prange, pndindex, gdb, gdb_breakpoint, gdb_init,
#      22     literally, literal_unroll
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\numba\misc\special.py in <module>
#       1 import numpy as np
#       2
# ----> 3 from numba.core.typing.typeof import typeof
#       4
#       5
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\numba\core\typing\__init__.py in <module>
# ----> 1 from .context import BaseContext, Context
#       2 from .templates import (signature, make_concrete_template, Signature,
#       3                         fold_arguments)
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\numba\core\typing\context.py in <module>
#       9 import numba
#      10 from numba.core import types, errors
# ---> 11 from numba.core.typeconv import Conversion, rules
#      12 from numba.core.typing import templates
#      13 from .typeof import typeof, Purpose
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\numba\core\typeconv\rules.py in <module>
#       1 import itertools
# ----> 2 from .typeconv import TypeManager, TypeCastingRules
#       3 from numba.core import types
#       4
#       5
#
# c:\users\me\appdata\local\programs\python\python36\lib\site-packages\numba\core\typeconv\typeconv.py in <module>
#      15            "possible please include the following in your error report:\n\n"
#      16            "sys.executable: %s\n")
# ---> 17     raise ImportError(msg % (url, reportme, str(e), sys.executable))
#      18
#      19 from numba.core.typeconv import castgraph, Conversion
#
# ImportError: Numba could not be imported.
# If you are seeing this message and are undertaking Numba development work, you may need to re-run:
#
# python setup.py build_ext --inplace
#
# (Also, please check the development set up guide http://numba.pydata.org/numba-doc/latest/developer/contributing.html.)
#
# If you are not working on Numba development:
#
# Please report the error message and traceback, along with a minimal reproducer
# at: https://github.com/numba/numba/issues/new
#
# If more help is needed please feel free to speak to the Numba core developers
# directly at: https://gitter.im/numba/numba
#
# Thanks in advance for your help in improving Numba!
#
# The original error was: 'DLL load failed: The specified module could not be found.'
# --------------------------------------------------------------------------------
# If possible please include the following in your error report:
#
# sys.executable: c:\users\me\appdata\local\programs\python\python36\python.exe

# %%
sns.boxplot(Data['TV'])

# %%
sns.boxplot(Data['Sales'])

# %%
sns.boxplot(Data['Newspaper'])

# %%
sns.boxplot(Data['Radio'])

# %%
x = Data[['TV']]
y = Data.Sales

# %%
x
# Out:
#         TV
# 0    230.1
# 1     44.5
# 2     17.2
# 3    151.5
# 4    180.8
# ..     ...
# 195   38.2
# 196   94.2
# 197  177.0
# 198  283.6
# 199  232.1
#
# [200 rows x 1 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
SLR = LinearRegression()

# %%
SLR.fit(x,y)
# Out:
# LinearRegression()

# %%
SLR.predict([[38.2]])  # 7.6
# Out:
# array([8.84849321])

# %%
Data.iloc[195]
# Out:
# TV           38.2
# Radio         3.7
# Newspaper    13.8
# Sales         7.6
# Name: 195, dtype: float64

# %%
x.shape
# Out:
# (200, 1)

# %%
y.shape
# Out:
# (200,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)  # Random ness

# %%
x_train.shape # 75% of Data
# Out:
# (150, 1)

# %%
x_train.head()
# Out:
#         TV
# 11   214.7
# 122  224.0
# 16    67.8
# 89   109.8
# 100  222.4

# %%
x_test.shape
# Out:
# (50, 1)

# %%
x_test.head()
# Out:
#         TV
# 171  164.5
# 145  140.3
# 24    62.3
# 184  253.8
# 177  170.2

# %%
y_train.shape
# Out:
# (150,)

# %%
y_test.shape
# Out:
# (50,)

# %%
SLR_MODEL = SLR.fit(x_train,y_train)  # Train a Model

# %%
SLR_MODEL
# Out:
# LinearRegression()

# %%
Train_Score = SLR_MODEL.score(x_train,y_train)

# %%
Train_Score
# Out:
# 0.6342314264100939

# %%
print("Train Score of a Model is ",Train_Score)
# Out:
# Train Score of a Model is  0.6342314264100939

# %%
Test_Score =SLR_MODEL.score(x_test,y_test)

# %%
Test_Score
# Out:
# 0.49971160743583753

# %%
print("Test Score of a Model is ",Test_Score)
# Out:
# Test Score of a Model is  0.49971160743583753

# %%
new_predication = SLR_MODEL.predict(x_test)
new_predication
# Out:
# array([14.90179026, 13.70618833,  9.85259534, 19.31366019, 15.18339898,
#        16.53709703, 10.54920638, 16.99656389, 18.11311776, 12.08076257,
#        19.89663965, 19.76324604, 20.90450243, 10.40099127,  8.65205291,
#        11.52742614, 14.95613581, 18.78996679, 11.41379455, 11.00867324,
#        20.67723925, 16.34441738, 12.56493195, 17.65859141, 10.07985852,
#        10.26265716, 18.05383171,  9.61545116, 10.54426588, 13.6666643 ,
#        18.63681117, 12.72796857,  8.97318566, 12.2437992 , 16.53709703,
#        13.45422264, 13.25166198, 18.24157086, 15.90965305, 15.45512669,
#        16.99162339,  8.03943043,  9.55122461,  8.8990781 , 11.20629339,
#        21.41831483, 14.85238523, 10.54920638,  7.42680795, 16.77918172])

# %%
pd.DataFrame({"Actul Data":y_test,
             "Predicted Data":new_predication,
             "Error":y_test-new_predication})
# Out:
#      Actul Data  Predicted Data     Error
# 171        14.5       14.901790 -0.401790
# 145        10.3       13.706188 -3.406188
# 24          9.7        9.852595 -0.152595
# 184        17.6       19.313660 -1.713660
# 177        11.7       15.183399 -3.483399
# 152        16.6       16.537097  0.062903
# 117         9.4       10.549206 -1.149206
# 43         12.9       16.996564 -4.096564
# 124        19.7       18.113118  1.586882
# 94         11.5       12.080763 -0.580763
# 33         17.4       19.896640 -2.496640
# 25         12.0       19.763246 -7.763246
# 188        15.9       20.904502 -5.004502
# 140        10.9       10.400991  0.499009
# 148        10.9        8.652053  2.247947
# 144        11.4       11.527426 -0.127426
# 179        12.6       14.956136 -2.356136
# 147        25.4       18.789967  6.610033
# 156        15.3       11.413795  3.886205
# 161        13.3       11.008673  2.291327
# 17         24.4       20.677239  3.722761
# 141        19.2       16.344417  2.855583
# 164        11.9       12.564932 -0.664932
# 128        24.7       17.658591  7.041409
# 49          9.7       10.079859 -0.379859
# 29         10.5       10.262657  0.237343
# 23         15.5       18.053832 -2.553832
# 6          11.8        9.615451  2.184549
# 86         12.0       10.544266  1.455734
# 186        10.3       13.666664 -3.366664
# 27         15.9       18.636811 -2.736811
# 77         14.2       12.727969  1.472031
# 1          10.4        8.973186  1.426814
# 87         16.0       12.243799  3.756201
# 96         11.7       16.537097 -4.837097
# 99         17.2       13.454223  3.745777
# 64         18.0       13.251662  4.748338
# 199        13.4       18.241571 -4.841571
# 97         15.5       15.909653 -0.409653
# 112        14.1       15.455127 -1.355127
# 167        12.2       16.991623 -4.791623
# 136         9.5        8.039430  1.460570
# 182         8.7        9.551225 -0.851225
# 138         9.6        8.899078  0.700922
# 46         10.6       11.206293 -0.606293
# 101        23.8       21.418315  2.381685
# 163        18.0       14.852385  3.147615
# 80         11.8       10.549206  1.250794
# 22          5.6        7.426808 -1.826808
# 40         16.6       16.779182 -0.179182

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
MSE = mean_squared_error(y_test,new_predication)

# %%
MSE
# Out:
# 9.393566946456055

# %%
MAE = mean_absolute_error(y_test,new_predication)

# %%
MAE
# Out:
# 2.418104471508015

# %%
plt.scatter(x,y)
plt.plot(x,SLR_MODEL.coef_*x +SLR_MODEL.intercept_,'-r')
plt.xlabel("TV")
plt.ylabel("Sales")
# Out:
# Text(0, 0.5, 'Sales')

# %%
x = Data[["Radio"]]

# %%
x
# Out:
#      Radio
# 0     37.8
# 1     39.3
# 2     45.9
# 3     41.3
# 4     10.8
# ..     ...
# 195    3.7
# 196    4.9
# 197    9.3
# 198   42.0
# 199    8.6
#
# [200 rows x 1 columns]

# %%
y = Data.Newspaper

# %%
y
# Out:
# 0      69.2
# 1      45.1
# 2      69.3
# 3      58.5
# 4      58.4
#        ...
# 195    13.8
# 196     8.1
# 197     6.4
# 198    66.2
# 199     8.7
# Name: Newspaper, Length: 200, dtype: float64

# %%
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
SLR = LinearRegression()

# %%
SLR
# Out:
# LinearRegression()

# %%
SLR.fit(x,y)
# Out:
# LinearRegression()

# %%
SLR.predict([[3.7]])
# Out:
# array([20.39185404])

# %%
Data.iloc[195]
# Out:
# TV           38.2
# Radio         3.7
# Newspaper    13.8
# Sales         7.6
# Name: 195, dtype: float64

# %%
x.shape
# Out:
# (200, 1)

# %%
y.shape
# Out:
# (200,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)  # Random ness

# %%
x_train.shape
# Out:
# (150, 1)

# %%
x_train.head()
# Out:
#      Radio
# 112   15.4
# 146    7.3
# 49    11.7
# 93    36.5
# 10     5.8

# %%
x_test.shape
# Out:
# (50, 1)

# %%
x_test.head()
# Out:
#      Radio
# 57    19.2
# 48    15.8
# 107    0.3
# 28    27.1
# 156   43.5

# %%
y_train.shape
# Out:
# (150,)

# %%
y_test.shape
# Out:
# (50,)

# %%
SLR_MODEL = SLR.fit(x_train,y_train)  # Train a Model

# %%
SLR_MODEL
# Out:
# LinearRegression()

# %%
Train_Score = SLR_MODEL.score(x_train,y_train)

# %%
print("Train Score of a Model is ",Train_Score)
# Out:
# Train Score of a Model is  0.10966625313871914

# %%
Test_Score =SLR_MODEL.score(x_test,y_test)

# %%
print("Test Score of a Model is ",Test_Score)
# Out:
# Test Score of a Model is  0.1710058830459441

# %%
new_predication = SLR_MODEL.predict(x_test)
new_predication
# Out:
# array([28.47092827, 26.83741316, 19.39050602, 32.26644869, 40.14575689,
#        21.98491238, 35.86979085, 32.93907256, 20.49553095, 30.44075532,
#        26.88545772, 27.51003703, 26.11674473, 29.47986408, 37.93570703,
#        33.41951818, 32.55471606, 35.34130067, 33.03516168, 42.74016324,
#        26.35696754, 42.98038606, 23.18602643, 23.71451662, 36.35023647,
#        32.74689431, 23.8586503 , 33.61169643, 37.40721684, 34.76476592,
#        23.28211556, 35.2932561 , 36.0619691 , 35.10107786, 19.9189962 ,
#        26.11674473, 24.33909593, 42.78820781, 32.17035956, 36.97481578,
#        32.31449325, 40.24184601, 26.69327947, 38.27201896, 19.24637233,
#        42.98038606, 32.55471606, 32.07427044, 28.99941846, 24.53127417])

# %%
pd.DataFrame({"Actul Data":y_test,
             "Predicted Data":new_predication,
             "Error":y_test-new_predication})
# Out:
#      Actul Data  Predicted Data      Error
# 57         16.6       28.470928 -11.870928
# 48         49.9       26.837413  23.062587
# 107        23.2       19.390506   3.809494
# 28         22.9       32.266449  -9.366449
# 156        50.5       40.145757  10.354243
# 182        29.7       21.984912   7.715088
# 123        12.4       35.869791 -23.469791
# 77         14.2       32.939073 -18.739073
# 9          21.2       20.495531   0.704469
# 152        14.2       30.440755 -16.240755
# 22         49.6       26.885458  22.714542
# 103        17.9       27.510037  -9.610037
# 116        25.6       26.116745  -0.516745
# 184        30.0       29.479864   0.520136
# 126        50.6       37.935707  12.664293
# 59          9.3       33.419518 -24.119518
# 20         53.4       32.554716  20.845284
# 133        45.1       35.341301   9.758699
# 187        18.2       33.035162 -14.835162
# 175        41.8       42.740163  -0.940163
# 144        38.9       26.356968  12.543032
# 37         45.7       42.980386   2.719614
# 110        56.5       23.186026  33.313974
# 65          0.9       23.714517 -22.814517
# 194         6.0       36.350236 -30.350236
# 56         41.4       32.746894   8.653106
# 51          3.6       23.858650 -20.258650
# 78          9.4       33.611696 -24.211696
# 0          69.2       37.407217  31.792783
# 124        74.2       34.764766  39.435234
# 151        48.7       23.282116  25.417884
# 41         38.7       35.293256   3.406744
# 115        52.7       36.061969  16.638031
# 72         19.3       35.101078 -15.801078
# 34          7.4       19.918996 -12.518996
# 71         31.7       26.116745   5.583255
# 169         6.4       24.339096 -17.939096
# 147        44.3       42.788208   1.511792
# 109         5.5       32.170360 -26.670360
# 158        45.2       36.974816   8.225184
# 132         2.1       32.314493 -30.214493
# 75         89.4       40.241846  49.158154
# 62         27.3       26.693279   0.606721
# 17         55.8       38.272019  17.527981
# 127         9.2       19.246372 -10.046372
# 55         60.0       42.980386  17.019614
# 42          1.8       32.554716 -30.754716
# 38         35.1       32.074270   3.025730
# 82         32.5       28.999418   3.500582
# 106        29.7       24.531274   5.168726

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
MSE = mean_squared_error(y_test,new_predication)

# %%
MSE
# Out:
# 361.20118918089867

# %%
MAE = mean_absolute_error(y_test,new_predication)

# %%
MAE
# Out:
# 15.373716137528806

# %%
plt.scatter(x,y)
plt.plot(x,SLR_MODEL.coef_*x +SLR_MODEL.intercept_,'-r')
plt.xlabel("Radio")
plt.ylabel("Newspaper")
# Out:
# Text(0, 0.5, 'Newspaper')
